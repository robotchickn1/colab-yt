# %% [markdown]
# First, some formalities

# %%
from google.colab import drive
import os

def setup_yt_dlp():
    # Mount Google Drive to save downloaded files
    drive.mount('/content/drive')

    # Install yt-dlp
    # !pip install yt-dlp
    print("Setup complete!")

# %% [markdown]
# In the cell below, place the youtube link in the `download_youtube_video` string. It can download playlists as well. All videos are by default in their highest resolution. Cheers, :)

# %%
def download_youtube_video(url, output_folder="/content/drive/MyDrive/YT"):
    os.makedirs(output_folder, exist_ok=True)

    # Command to download the best video and audio format
    # !yt-dlp -o "{output_folder}/%(title)s.%(ext)s" {url}
    print(f"Download complete! Files saved to {output_folder}")


setup_yt_dlp()
download_youtube_video("https://www.youtube.com/playlist?list=PLBRgytHojT9YJTbYga3IRwxbNvIyboIlb")
